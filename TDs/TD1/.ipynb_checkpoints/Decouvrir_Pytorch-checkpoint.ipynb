# %% [markdown]
# ## Introduction à Pytorch

# %% [markdown]
# https://ipython.readthedocs.io/en/stable/install/kernel_install.html#kernels-for-different-environments

# %% [markdown]
# # Pourquoi apprendre Pytorch ?
#
# * Momentum dans la recherche
# https://trends.google.com/trends/explore?date=all&geo=FR&q=pytorch,keras&hl=fr
#
# * Pytorch est très performant
#
# ![Performance of frameworks](https://unfoldai.com/storage/2024/08/keras-pytorch-performance.jpg)

# %% [markdown]
# ## Pourquoi PyTorch pourrait être préféré à Keras : Une comparaison
#
# **PyTorch** et **Keras** sont deux bibliothèques Python populaires pour le deep learning, chacune avec ses forces et ses faiblesses. Choisir l'une ou l'autre dépend souvent des besoins spécifiques du projet. Voici quelques raisons pour lesquelles un développeur pourrait préférer PyTorch à Keras :
#
# ### 1. **Flexibilité et contrôle:**
# * **Graphiques dynamiques:** PyTorch offre une grande flexibilité grâce à ses graphiques dynamiques, permettant de modifier le modèle à la volée. Cela est particulièrement utile pour la recherche et les modèles expérimentaux.
# * **Bas niveau:** PyTorch est plus proche du matériel, ce qui donne un meilleur contrôle sur l'optimisation et le débogage.
# * **Intégration avec d'autres outils:** PyTorch s'intègre facilement avec d'autres bibliothèques Python, ce qui le rend très polyvalent.
#
# ### 2. **Communauté et écosystème:**
# * **Recherche active:** PyTorch est très populaire dans la communauté de recherche en apprentissage profond, ce qui signifie que de nouvelles fonctionnalités et améliorations sont souvent ajoutées.
# * **Grand écosystème:** PyTorch dispose d'un écosystème riche et en constante évolution, avec de nombreux outils et bibliothèques complémentaires.
#
# ### 3. **Performances:**
# * **Tensor opérations:** PyTorch offre des performances élevées grâce à son optimisation des opérations sur les tenseurs.
# * **GPU accélération:** PyTorch est bien intégré avec les GPU, ce qui est essentiel pour les modèles de deep learning exigeants.
#
# ### 4. **Pythonic:**
# * **Naturel:** PyTorch est conçu pour être très Pythonic, ce qui facilite l'apprentissage et l'utilisation pour les développeurs Python expérimentés.

# %% [markdown]
# # Un entrainement classique
#
#
# ## De quoi avons besoin pour entrainer un réseau de neurones ?
#
# 1. Des données labélisées
# 2. Un fonction de cout
# 3. Un optimiseur
# 4. Des hyperparamètres

# %% [markdown]
# # Importation des librairies

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
# Créeons un dataset pour modéliser la fonction sinus

seed = 2024
N = 100
x= np.random.rand(N)
y = np.sin(2*np.pi*x)

#Generate training data
percentage_of_training_data = 0.3

dataset_indexes = np.arange(N)

train_indexes = np.random.choice(np.arange(N),size = int(percentage_of_training_data*N), replace = False)
#generate test data
val_indexes = list(set(dataset_indexes).difference(set(train_indexes)))

x_train= x[train_indexes]
y_train = y[train_indexes]
x_val = x[val_indexes]
y_val=y[val_indexes]


device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Affichage

plt.scatter(x_train,y_train)
plt.title("Train data")
# Out:
# Text(0.5, 1.0, 'Train data')

# %%
# Affichage

plt.scatter(x_val,y_val)
plt.title("Val data")
# Out:
# Text(0.5, 1.0, 'Val data')

# %% [markdown]
# # Modèle

# %%
# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, out_dim):
        """
        Args
        input_size : Taille d'entrée
        hidden_size : dimension couches cachées
        out_dim : dimension de sortie

        """
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.activation = nn.Sigmoid()
        self.fc2 = nn.Linear(hidden_size, hidden_size)  
        self.fc3 = nn.Linear(hidden_size, out_dim) 

    
    def forward(self, x):
        
        out = self.fc1(x)
        out = self.activation(out)
        out = self.fc2(out)
        out = self.activation(out)
        out = self.fc3(out)
        return out

    
    # Fully connected neural network with one hidden layer
class SequentialNeuralNet(nn.Module):
    
    def __init__(self, input_size, hidden_size, out_dim):
        """
        Args
        input_size : Taille d'entrée
        hidden_size : dimension couches cachées
        out_dim : dimension de sortie

        """
        super(NeuralNet, self).__init__()
        self.model = nn.Sequential(nn.Linear(input_size, hidden_size),
                                  nn.Sigmoid(),
                                  nn.Linear(hidden_size,hidden_size),
                                  nn.Sigmoid(),
                                  nn.Linear(hidden_size,out_dim))
 
    
    def forward(self, x):
        out = self.model(x)
        return out

# %%
input_size = 1
hidden_size = 32
num_classes = 1
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# %%
#Model parameters

for name, param in model.named_parameters():
    print(name , param, param.requires_grad, "\n"+"----------------------------------"*2)
# Out:
# fc1.weight Parameter containing:
# tensor([[-1.5983],
#         [-1.5451],
#         [ 0.9505],
#         [ 0.3826],
#         [-1.2402],
#         [ 1.0593],
#         [ 0.8068],
#         [ 1.4876],
#         [-1.6226],
#         [-1.6283],
#         [ 1.0243],
#         [-0.6429],
#         [ 1.0667],
#         [-1.0485],
#         [ 1.7019],
#         [-1.1281],
#         [-1.4506],
#         [-1.2061],
#         [ 0.9561],
#         [ 0.5214],
#         [-0.9944],
#         [ 1.0834],
#         [-0.7229],
#         [-1.0634],
#         [-1.5182],
#         [ 0.7978],
#         [ 0.7983],
#         [ 0.7476],
#         [ 0.1438],
#         [ 0.6264],
#         [ 1.6154],
#         [ 0.3522]], requires_grad=True) True
# --------------------------------------------------------------------
# fc1.bias Parameter containing:
# tensor([-0.2321,  0.3236,  0.4963, -0.3201,  0.0246,  0.3468, -0.8045, -0.0036,
#         -0.2226,  0.2668, -0.0450,  0.7334, -0.2971, -0.5965, -0.7279,  0.2719,
#          0.7180,  0.6881,  0.0559, -0.6937,  0.7214, -0.6849,  0.6332, -0.3113,
#         -0.3240,  0.7035,  0.4190,  0.3546,  0.1618, -0.7733, -0.5332,  0.1341],
#        requires_grad=True) True
# --------------------------------------------------------------------
# fc2.weight Parameter containing:
# tensor([[-0.4538, -0.3263,  0.0817,  ...,  0.0133,  0.2246,  0.1239],
#         [ 0.2011,  0.4567, -0.2138,  ...,  0.0069, -0.3031,  0.1122],
#         [-0.5310, -0.2231,  0.2563,  ..., -0.0212,  0.2742, -0.0433],
#         ...,
#         [-0.4506, -0.3671,  0.0366,  ..., -0.0738,  0.2740, -0.0036],
#         [-0.1714, -0.1725,  0.0879,  ...,  0.2185,  0.2882,  0.0125],
#         [-0.3217, -0.4639,  0.1888,  ...,  0.0370,  0.3503,  0.1712]],
#        requires_grad=True) True
# --------------------------------------------------------------------
# fc2.bias Parameter containing:
# tensor([ 0.0264, -0.0364, -0.0406,  0.0257, -0.0272, -0.0162,  0.0082,  0.0988,
#         -0.1655, -0.0387,  0.0045,  0.1554, -0.1224, -0.0738, -0.0451,  0.0664,
#         -0.0461, -0.1526, -0.1324,  0.0685,  0.0643,  0.0336, -0.0740,  0.0466,
#          0.1424,  0.0717,  0.0546, -0.1434,  0.1257,  0.0903, -0.1437,  0.0603],
#        requires_grad=True) True
# --------------------------------------------------------------------
# fc3.weight Parameter containing:
# tensor([[-0.2086,  0.2889, -0.1837,  0.2366, -0.2222,  0.2524, -0.2141, -0.2463,
#          -0.1793, -0.0855,  0.2481,  0.1763, -0.1676,  0.2579, -0.1847,  0.2177,
#          -0.1179,  0.1910,  0.2614,  0.1900,  0.1306,  0.1513, -0.1681, -0.2607,
#          -0.1752, -0.1780,  0.2995,  0.2110, -0.1677, -0.1800, -0.2010, -0.1797]],
#        requires_grad=True) True
# --------------------------------------------------------------------
# fc3.bias Parameter containing:
# tensor([0.0363], requires_grad=True) True
# --------------------------------------------------------------------

# %% [markdown]
# # Fonction de cout

# %%
# Loss and optimizer
criterion = nn.MSELoss()

# %% [markdown]
# # Optimiseur

# %%
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Entrainement du modèle

# %%
# Train the model
batch_size = 10
num_epochs = 500
N_train = x_train.shape[0]
batch_per_epoch = N_train//batch_size
batch_per_epoch = batch_per_epoch +1 if N_train%batch_per_epoch != 0 else batch_per_epoch

x_train = torch.tensor(x_train,dtype=torch.float32).reshape(-1,1)
y_train = torch.tensor(y_train,dtype=torch.float32).reshape(-1,1)

model.train()

for epoch in range(num_epochs):
    avg_loss = 0.0
    for i in range(batch_per_epoch):  
        # Move tensors to the configured device
        start= i*batch_size
        end = min(N_train, (i+1)*batch_size)
        x_train_batch =x_train[start:end].to(device)
        y_train_batch =y_train[start:end].to(device)

        
        # Forward pass
        y_batch_pred = model(x_train_batch)
        loss = criterion(y_batch_pred, y_train_batch)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg_loss +=loss
        
    avg_loss/=batch_per_epoch
        
        #if (i+1) % 100 == 0:
    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
           .format(epoch+1, num_epochs, i+1, batch_per_epoch, avg_loss.item()))
# Out:
# Epoch [1/500], Step [3/3], Loss: 0.6104
# Epoch [2/500], Step [3/3], Loss: 0.5887
# Epoch [3/500], Step [3/3], Loss: 0.5784
# Epoch [4/500], Step [3/3], Loss: 0.5749
# Epoch [5/500], Step [3/3], Loss: 0.5741
# Epoch [6/500], Step [3/3], Loss: 0.5733
# Epoch [7/500], Step [3/3], Loss: 0.5715
# Epoch [8/500], Step [3/3], Loss: 0.5692
# Epoch [9/500], Step [3/3], Loss: 0.5668
# Epoch [10/500], Step [3/3], Loss: 0.5650
# Epoch [11/500], Step [3/3], Loss: 0.5637
# Epoch [12/500], Step [3/3], Loss: 0.5627
# Epoch [13/500], Step [3/3], Loss: 0.5618
# Epoch [14/500], Step [3/3], Loss: 0.5607
# Epoch [15/500], Step [3/3], Loss: 0.5594
# Epoch [16/500], Step [3/3], Loss: 0.5580
# Epoch [17/500], Step [3/3], Loss: 0.5566
# Epoch [18/500], Step [3/3], Loss: 0.5552
# Epoch [19/500], Step [3/3], Loss: 0.5537
# Epoch [20/500], Step [3/3], Loss: 0.5522
# Epoch [21/500], Step [3/3], Loss: 0.5506
# Epoch [22/500], Step [3/3], Loss: 0.5491
# Epoch [23/500], Step [3/3], Loss: 0.5476
# Epoch [24/500], Step [3/3], Loss: 0.5460
# Epoch [25/500], Step [3/3], Loss: 0.5444
# Epoch [26/500], Step [3/3], Loss: 0.5429
# Epoch [27/500], Step [3/3], Loss: 0.5413
# Epoch [28/500], Step [3/3], Loss: 0.5397
# Epoch [29/500], Step [3/3], Loss: 0.5380
# Epoch [30/500], Step [3/3], Loss: 0.5363
# Epoch [31/500], Step [3/3], Loss: 0.5345
# Epoch [32/500], Step [3/3], Loss: 0.5328
# Epoch [33/500], Step [3/3], Loss: 0.5309
# Epoch [34/500], Step [3/3], Loss: 0.5291
# Epoch [35/500], Step [3/3], Loss: 0.5272
# Epoch [36/500], Step [3/3], Loss: 0.5253
# Epoch [37/500], Step [3/3], Loss: 0.5233
# Epoch [38/500], Step [3/3], Loss: 0.5213
# Epoch [39/500], Step [3/3], Loss: 0.5193
# Epoch [40/500], Step [3/3], Loss: 0.5172
# Epoch [41/500], Step [3/3], Loss: 0.5151
# Epoch [42/500], Step [3/3], Loss: 0.5129
# Epoch [43/500], Step [3/3], Loss: 0.5107
# Epoch [44/500], Step [3/3], Loss: 0.5084
# Epoch [45/500], Step [3/3], Loss: 0.5061
# Epoch [46/500], Step [3/3], Loss: 0.5038
# Epoch [47/500], Step [3/3], Loss: 0.5014
# Epoch [48/500], Step [3/3], Loss: 0.4989
# Epoch [49/500], Step [3/3], Loss: 0.4964
# Epoch [50/500], Step [3/3], Loss: 0.4938
# Epoch [51/500], Step [3/3], Loss: 0.4912
# Epoch [52/500], Step [3/3], Loss: 0.4886
# Epoch [53/500], Step [3/3], Loss: 0.4859
# Epoch [54/500], Step [3/3], Loss: 0.4831
# Epoch [55/500], Step [3/3], Loss: 0.4802
# Epoch [56/500], Step [3/3], Loss: 0.4774
# Epoch [57/500], Step [3/3], Loss: 0.4744
# Epoch [58/500], Step [3/3], Loss: 0.4714
# Epoch [59/500], Step [3/3], Loss: 0.4683
# Epoch [60/500], Step [3/3], Loss: 0.4652
# Epoch [61/500], Step [3/3], Loss: 0.4620
# Epoch [62/500], Step [3/3], Loss: 0.4587
# Epoch [63/500], Step [3/3], Loss: 0.4554
# Epoch [64/500], Step [3/3], Loss: 0.4520
# Epoch [65/500], Step [3/3], Loss: 0.4486
# Epoch [66/500], Step [3/3], Loss: 0.4451
# Epoch [67/500], Step [3/3], Loss: 0.4415
# Epoch [68/500], Step [3/3], Loss: 0.4379
# Epoch [69/500], Step [3/3], Loss: 0.4342
# Epoch [70/500], Step [3/3], Loss: 0.4304
# Epoch [71/500], Step [3/3], Loss: 0.4266
# Epoch [72/500], Step [3/3], Loss: 0.4227
# Epoch [73/500], Step [3/3], Loss: 0.4187
# Epoch [74/500], Step [3/3], Loss: 0.4147
# Epoch [75/500], Step [3/3], Loss: 0.4106
# Epoch [76/500], Step [3/3], Loss: 0.4065
# Epoch [77/500], Step [3/3], Loss: 0.4023
# Epoch [78/500], Step [3/3], Loss: 0.3981
# Epoch [79/500], Step [3/3], Loss: 0.3938
# Epoch [80/500], Step [3/3], Loss: 0.3894
# Epoch [81/500], Step [3/3], Loss: 0.3850
# Epoch [82/500], Step [3/3], Loss: 0.3805
# Epoch [83/500], Step [3/3], Loss: 0.3760
# Epoch [84/500], Step [3/3], Loss: 0.3715
# Epoch [85/500], Step [3/3], Loss: 0.3669
# Epoch [86/500], Step [3/3], Loss: 0.3622
# Epoch [87/500], Step [3/3], Loss: 0.3576
# Epoch [88/500], Step [3/3], Loss: 0.3529
# Epoch [89/500], Step [3/3], Loss: 0.3481
# Epoch [90/500], Step [3/3], Loss: 0.3434
# Epoch [91/500], Step [3/3], Loss: 0.3386
# Epoch [92/500], Step [3/3], Loss: 0.3338
# Epoch [93/500], Step [3/3], Loss: 0.3290
# Epoch [94/500], Step [3/3], Loss: 0.3241
# Epoch [95/500], Step [3/3], Loss: 0.3193
# Epoch [96/500], Step [3/3], Loss: 0.3145
# Epoch [97/500], Step [3/3], Loss: 0.3096
# Epoch [98/500], Step [3/3], Loss: 0.3048
# Epoch [99/500], Step [3/3], Loss: 0.3000
# Epoch [100/500], Step [3/3], Loss: 0.2952
# Epoch [101/500], Step [3/3], Loss: 0.2904
# Epoch [102/500], Step [3/3], Loss: 0.2857
# Epoch [103/500], Step [3/3], Loss: 0.2810
# Epoch [104/500], Step [3/3], Loss: 0.2763
# Epoch [105/500], Step [3/3], Loss: 0.2717
# Epoch [106/500], Step [3/3], Loss: 0.2671
# Epoch [107/500], Step [3/3], Loss: 0.2626
# Epoch [108/500], Step [3/3], Loss: 0.2581
# Epoch [109/500], Step [3/3], Loss: 0.2537
# Epoch [110/500], Step [3/3], Loss: 0.2493
# Epoch [111/500], Step [3/3], Loss: 0.2451
# Epoch [112/500], Step [3/3], Loss: 0.2409
# Epoch [113/500], Step [3/3], Loss: 0.2367
# Epoch [114/500], Step [3/3], Loss: 0.2327
# Epoch [115/500], Step [3/3], Loss: 0.2287
# Epoch [116/500], Step [3/3], Loss: 0.2249
# Epoch [117/500], Step [3/3], Loss: 0.2211
# Epoch [118/500], Step [3/3], Loss: 0.2174
# Epoch [119/500], Step [3/3], Loss: 0.2138
# Epoch [120/500], Step [3/3], Loss: 0.2104
# Epoch [121/500], Step [3/3], Loss: 0.2070
# Epoch [122/500], Step [3/3], Loss: 0.2037
# Epoch [123/500], Step [3/3], Loss: 0.2005
# Epoch [124/500], Step [3/3], Loss: 0.1975
# Epoch [125/500], Step [3/3], Loss: 0.1945
# Epoch [126/500], Step [3/3], Loss: 0.1917
# Epoch [127/500], Step [3/3], Loss: 0.1889
# Epoch [128/500], Step [3/3], Loss: 0.1863
# Epoch [129/500], Step [3/3], Loss: 0.1837
# Epoch [130/500], Step [3/3], Loss: 0.1813
# Epoch [131/500], Step [3/3], Loss: 0.1790
# Epoch [132/500], Step [3/3], Loss: 0.1768
# Epoch [133/500], Step [3/3], Loss: 0.1747
# Epoch [134/500], Step [3/3], Loss: 0.1726
# Epoch [135/500], Step [3/3], Loss: 0.1707
# Epoch [136/500], Step [3/3], Loss: 0.1689
# Epoch [137/500], Step [3/3], Loss: 0.1672
# Epoch [138/500], Step [3/3], Loss: 0.1655
# Epoch [139/500], Step [3/3], Loss: 0.1640
# Epoch [140/500], Step [3/3], Loss: 0.1625
# Epoch [141/500], Step [3/3], Loss: 0.1611
# Epoch [142/500], Step [3/3], Loss: 0.1598
# Epoch [143/500], Step [3/3], Loss: 0.1586
# Epoch [144/500], Step [3/3], Loss: 0.1574
# Epoch [145/500], Step [3/3], Loss: 0.1563
# Epoch [146/500], Step [3/3], Loss: 0.1553
# Epoch [147/500], Step [3/3], Loss: 0.1544
# Epoch [148/500], Step [3/3], Loss: 0.1535
# Epoch [149/500], Step [3/3], Loss: 0.1527
# Epoch [150/500], Step [3/3], Loss: 0.1519
# Epoch [151/500], Step [3/3], Loss: 0.1511
# Epoch [152/500], Step [3/3], Loss: 0.1505
# Epoch [153/500], Step [3/3], Loss: 0.1498
# Epoch [154/500], Step [3/3], Loss: 0.1493
# Epoch [155/500], Step [3/3], Loss: 0.1487
# Epoch [156/500], Step [3/3], Loss: 0.1482
# Epoch [157/500], Step [3/3], Loss: 0.1477
# Epoch [158/500], Step [3/3], Loss: 0.1473
# Epoch [159/500], Step [3/3], Loss: 0.1469
# Epoch [160/500], Step [3/3], Loss: 0.1465
# Epoch [161/500], Step [3/3], Loss: 0.1462
# Epoch [162/500], Step [3/3], Loss: 0.1459
# Epoch [163/500], Step [3/3], Loss: 0.1456
# Epoch [164/500], Step [3/3], Loss: 0.1453
# Epoch [165/500], Step [3/3], Loss: 0.1451
# Epoch [166/500], Step [3/3], Loss: 0.1449
# Epoch [167/500], Step [3/3], Loss: 0.1447
# Epoch [168/500], Step [3/3], Loss: 0.1445
# Epoch [169/500], Step [3/3], Loss: 0.1443
# Epoch [170/500], Step [3/3], Loss: 0.1441
# Epoch [171/500], Step [3/3], Loss: 0.1440
# Epoch [172/500], Step [3/3], Loss: 0.1438
# Epoch [173/500], Step [3/3], Loss: 0.1437
# Epoch [174/500], Step [3/3], Loss: 0.1436
# Epoch [175/500], Step [3/3], Loss: 0.1435
# Epoch [176/500], Step [3/3], Loss: 0.1434
# Epoch [177/500], Step [3/3], Loss: 0.1433
# Epoch [178/500], Step [3/3], Loss: 0.1432
# Epoch [179/500], Step [3/3], Loss: 0.1432
# Epoch [180/500], Step [3/3], Loss: 0.1431
# Epoch [181/500], Step [3/3], Loss: 0.1430
# Epoch [182/500], Step [3/3], Loss: 0.1430
# Epoch [183/500], Step [3/3], Loss: 0.1429
# Epoch [184/500], Step [3/3], Loss: 0.1429
# Epoch [185/500], Step [3/3], Loss: 0.1428
# Epoch [186/500], Step [3/3], Loss: 0.1428
# Epoch [187/500], Step [3/3], Loss: 0.1428
# Epoch [188/500], Step [3/3], Loss: 0.1427
# Epoch [189/500], Step [3/3], Loss: 0.1427
# Epoch [190/500], Step [3/3], Loss: 0.1427
# Epoch [191/500], Step [3/3], Loss: 0.1426
# Epoch [192/500], Step [3/3], Loss: 0.1426
# Epoch [193/500], Step [3/3], Loss: 0.1426
# Epoch [194/500], Step [3/3], Loss: 0.1426
# Epoch [195/500], Step [3/3], Loss: 0.1425
# Epoch [196/500], Step [3/3], Loss: 0.1425
# Epoch [197/500], Step [3/3], Loss: 0.1425
# Epoch [198/500], Step [3/3], Loss: 0.1425
# Epoch [199/500], Step [3/3], Loss: 0.1425
# Epoch [200/500], Step [3/3], Loss: 0.1425
# Epoch [201/500], Step [3/3], Loss: 0.1425
# Epoch [202/500], Step [3/3], Loss: 0.1424
# Epoch [203/500], Step [3/3], Loss: 0.1424
# Epoch [204/500], Step [3/3], Loss: 0.1424
# Epoch [205/500], Step [3/3], Loss: 0.1424
# Epoch [206/500], Step [3/3], Loss: 0.1424
# Epoch [207/500], Step [3/3], Loss: 0.1424
# Epoch [208/500], Step [3/3], Loss: 0.1424
# Epoch [209/500], Step [3/3], Loss: 0.1424
# Epoch [210/500], Step [3/3], Loss: 0.1424
# Epoch [211/500], Step [3/3], Loss: 0.1424
# Epoch [212/500], Step [3/3], Loss: 0.1424
# Epoch [213/500], Step [3/3], Loss: 0.1424
# Epoch [214/500], Step [3/3], Loss: 0.1423
# Epoch [215/500], Step [3/3], Loss: 0.1423
# Epoch [216/500], Step [3/3], Loss: 0.1423
# Epoch [217/500], Step [3/3], Loss: 0.1423
# Epoch [218/500], Step [3/3], Loss: 0.1423
# Epoch [219/500], Step [3/3], Loss: 0.1423
# Epoch [220/500], Step [3/3], Loss: 0.1423
# Epoch [221/500], Step [3/3], Loss: 0.1423
# Epoch [222/500], Step [3/3], Loss: 0.1423
# Epoch [223/500], Step [3/3], Loss: 0.1423
# Epoch [224/500], Step [3/3], Loss: 0.1423
# Epoch [225/500], Step [3/3], Loss: 0.1423
# Epoch [226/500], Step [3/3], Loss: 0.1423
# Epoch [227/500], Step [3/3], Loss: 0.1423
# Epoch [228/500], Step [3/3], Loss: 0.1423
# Epoch [229/500], Step [3/3], Loss: 0.1423
# Epoch [230/500], Step [3/3], Loss: 0.1423
# Epoch [231/500], Step [3/3], Loss: 0.1423
# Epoch [232/500], Step [3/3], Loss: 0.1423
# Epoch [233/500], Step [3/3], Loss: 0.1423
# Epoch [234/500], Step [3/3], Loss: 0.1423
# Epoch [235/500], Step [3/3], Loss: 0.1422
# Epoch [236/500], Step [3/3], Loss: 0.1422
# Epoch [237/500], Step [3/3], Loss: 0.1422
# Epoch [238/500], Step [3/3], Loss: 0.1422
# Epoch [239/500], Step [3/3], Loss: 0.1422
# Epoch [240/500], Step [3/3], Loss: 0.1422
# Epoch [241/500], Step [3/3], Loss: 0.1422
# Epoch [242/500], Step [3/3], Loss: 0.1422
# Epoch [243/500], Step [3/3], Loss: 0.1422
# Epoch [244/500], Step [3/3], Loss: 0.1422
# Epoch [245/500], Step [3/3], Loss: 0.1422
# Epoch [246/500], Step [3/3], Loss: 0.1422
# Epoch [247/500], Step [3/3], Loss: 0.1422
# Epoch [248/500], Step [3/3], Loss: 0.1422
# Epoch [249/500], Step [3/3], Loss: 0.1422
# Epoch [250/500], Step [3/3], Loss: 0.1422
# Epoch [251/500], Step [3/3], Loss: 0.1422
# Epoch [252/500], Step [3/3], Loss: 0.1422
# Epoch [253/500], Step [3/3], Loss: 0.1422
# Epoch [254/500], Step [3/3], Loss: 0.1422
# Epoch [255/500], Step [3/3], Loss: 0.1422
# Epoch [256/500], Step [3/3], Loss: 0.1422
# Epoch [257/500], Step [3/3], Loss: 0.1422
# Epoch [258/500], Step [3/3], Loss: 0.1422
# Epoch [259/500], Step [3/3], Loss: 0.1421
# Epoch [260/500], Step [3/3], Loss: 0.1421
# Epoch [261/500], Step [3/3], Loss: 0.1421
# Epoch [262/500], Step [3/3], Loss: 0.1421
# Epoch [263/500], Step [3/3], Loss: 0.1421
# Epoch [264/500], Step [3/3], Loss: 0.1421
# Epoch [265/500], Step [3/3], Loss: 0.1421
# Epoch [266/500], Step [3/3], Loss: 0.1421
# Epoch [267/500], Step [3/3], Loss: 0.1421
# Epoch [268/500], Step [3/3], Loss: 0.1421
# Epoch [269/500], Step [3/3], Loss: 0.1421
# Epoch [270/500], Step [3/3], Loss: 0.1421
# Epoch [271/500], Step [3/3], Loss: 0.1421
# Epoch [272/500], Step [3/3], Loss: 0.1421
# Epoch [273/500], Step [3/3], Loss: 0.1421
# Epoch [274/500], Step [3/3], Loss: 0.1421
# Epoch [275/500], Step [3/3], Loss: 0.1421
# Epoch [276/500], Step [3/3], Loss: 0.1421
# Epoch [277/500], Step [3/3], Loss: 0.1421
# Epoch [278/500], Step [3/3], Loss: 0.1421
# Epoch [279/500], Step [3/3], Loss: 0.1421
# Epoch [280/500], Step [3/3], Loss: 0.1421
# Epoch [281/500], Step [3/3], Loss: 0.1421
# Epoch [282/500], Step [3/3], Loss: 0.1421
# Epoch [283/500], Step [3/3], Loss: 0.1420
# Epoch [284/500], Step [3/3], Loss: 0.1420
# Epoch [285/500], Step [3/3], Loss: 0.1420
# Epoch [286/500], Step [3/3], Loss: 0.1420
# Epoch [287/500], Step [3/3], Loss: 0.1420
# Epoch [288/500], Step [3/3], Loss: 0.1420
# Epoch [289/500], Step [3/3], Loss: 0.1420
# Epoch [290/500], Step [3/3], Loss: 0.1420
# Epoch [291/500], Step [3/3], Loss: 0.1420
# Epoch [292/500], Step [3/3], Loss: 0.1420
# Epoch [293/500], Step [3/3], Loss: 0.1420
# Epoch [294/500], Step [3/3], Loss: 0.1420
# Epoch [295/500], Step [3/3], Loss: 0.1420
# Epoch [296/500], Step [3/3], Loss: 0.1420
# Epoch [297/500], Step [3/3], Loss: 0.1420
# Epoch [298/500], Step [3/3], Loss: 0.1420
# Epoch [299/500], Step [3/3], Loss: 0.1420
# Epoch [300/500], Step [3/3], Loss: 0.1420
# Epoch [301/500], Step [3/3], Loss: 0.1420
# Epoch [302/500], Step [3/3], Loss: 0.1420
# Epoch [303/500], Step [3/3], Loss: 0.1420
# Epoch [304/500], Step [3/3], Loss: 0.1420
# Epoch [305/500], Step [3/3], Loss: 0.1420
# Epoch [306/500], Step [3/3], Loss: 0.1420
# Epoch [307/500], Step [3/3], Loss: 0.1420
# Epoch [308/500], Step [3/3], Loss: 0.1419
# Epoch [309/500], Step [3/3], Loss: 0.1419
# Epoch [310/500], Step [3/3], Loss: 0.1419
# Epoch [311/500], Step [3/3], Loss: 0.1419
# Epoch [312/500], Step [3/3], Loss: 0.1419
# Epoch [313/500], Step [3/3], Loss: 0.1419
# Epoch [314/500], Step [3/3], Loss: 0.1419
# Epoch [315/500], Step [3/3], Loss: 0.1419
# Epoch [316/500], Step [3/3], Loss: 0.1419
# Epoch [317/500], Step [3/3], Loss: 0.1419
# Epoch [318/500], Step [3/3], Loss: 0.1419
# Epoch [319/500], Step [3/3], Loss: 0.1419
# Epoch [320/500], Step [3/3], Loss: 0.1419
# Epoch [321/500], Step [3/3], Loss: 0.1419
# Epoch [322/500], Step [3/3], Loss: 0.1419
# Epoch [323/500], Step [3/3], Loss: 0.1419
# Epoch [324/500], Step [3/3], Loss: 0.1419
# Epoch [325/500], Step [3/3], Loss: 0.1419
# Epoch [326/500], Step [3/3], Loss: 0.1419
# Epoch [327/500], Step [3/3], Loss: 0.1419
# Epoch [328/500], Step [3/3], Loss: 0.1419
# Epoch [329/500], Step [3/3], Loss: 0.1419
# Epoch [330/500], Step [3/3], Loss: 0.1419
# Epoch [331/500], Step [3/3], Loss: 0.1418
# Epoch [332/500], Step [3/3], Loss: 0.1418
# Epoch [333/500], Step [3/3], Loss: 0.1418
# Epoch [334/500], Step [3/3], Loss: 0.1418
# Epoch [335/500], Step [3/3], Loss: 0.1418
# Epoch [336/500], Step [3/3], Loss: 0.1418
# Epoch [337/500], Step [3/3], Loss: 0.1418
# Epoch [338/500], Step [3/3], Loss: 0.1418
# Epoch [339/500], Step [3/3], Loss: 0.1418
# Epoch [340/500], Step [3/3], Loss: 0.1418
# Epoch [341/500], Step [3/3], Loss: 0.1418
# Epoch [342/500], Step [3/3], Loss: 0.1418
# Epoch [343/500], Step [3/3], Loss: 0.1418
# Epoch [344/500], Step [3/3], Loss: 0.1418
# Epoch [345/500], Step [3/3], Loss: 0.1418
# Epoch [346/500], Step [3/3], Loss: 0.1418
# Epoch [347/500], Step [3/3], Loss: 0.1418
# Epoch [348/500], Step [3/3], Loss: 0.1418
# Epoch [349/500], Step [3/3], Loss: 0.1418
# Epoch [350/500], Step [3/3], Loss: 0.1418
# Epoch [351/500], Step [3/3], Loss: 0.1418
# Epoch [352/500], Step [3/3], Loss: 0.1418
# Epoch [353/500], Step [3/3], Loss: 0.1418
# Epoch [354/500], Step [3/3], Loss: 0.1418
# Epoch [355/500], Step [3/3], Loss: 0.1417
# Epoch [356/500], Step [3/3], Loss: 0.1417
# Epoch [357/500], Step [3/3], Loss: 0.1417
# Epoch [358/500], Step [3/3], Loss: 0.1417
# Epoch [359/500], Step [3/3], Loss: 0.1417
# Epoch [360/500], Step [3/3], Loss: 0.1417
# Epoch [361/500], Step [3/3], Loss: 0.1417
# Epoch [362/500], Step [3/3], Loss: 0.1417
# Epoch [363/500], Step [3/3], Loss: 0.1417
# Epoch [364/500], Step [3/3], Loss: 0.1417
# Epoch [365/500], Step [3/3], Loss: 0.1417
# Epoch [366/500], Step [3/3], Loss: 0.1417
# Epoch [367/500], Step [3/3], Loss: 0.1417
# Epoch [368/500], Step [3/3], Loss: 0.1417
# Epoch [369/500], Step [3/3], Loss: 0.1417
# Epoch [370/500], Step [3/3], Loss: 0.1417
# Epoch [371/500], Step [3/3], Loss: 0.1417
# Epoch [372/500], Step [3/3], Loss: 0.1417
# Epoch [373/500], Step [3/3], Loss: 0.1417
# Epoch [374/500], Step [3/3], Loss: 0.1417
# Epoch [375/500], Step [3/3], Loss: 0.1417
# Epoch [376/500], Step [3/3], Loss: 0.1417
# Epoch [377/500], Step [3/3], Loss: 0.1416
# Epoch [378/500], Step [3/3], Loss: 0.1416
# Epoch [379/500], Step [3/3], Loss: 0.1416
# Epoch [380/500], Step [3/3], Loss: 0.1416
# Epoch [381/500], Step [3/3], Loss: 0.1416
# Epoch [382/500], Step [3/3], Loss: 0.1416
# Epoch [383/500], Step [3/3], Loss: 0.1416
# Epoch [384/500], Step [3/3], Loss: 0.1416
# Epoch [385/500], Step [3/3], Loss: 0.1416
# Epoch [386/500], Step [3/3], Loss: 0.1416
# Epoch [387/500], Step [3/3], Loss: 0.1416
# Epoch [388/500], Step [3/3], Loss: 0.1416
# Epoch [389/500], Step [3/3], Loss: 0.1416
# Epoch [390/500], Step [3/3], Loss: 0.1416
# Epoch [391/500], Step [3/3], Loss: 0.1416
# Epoch [392/500], Step [3/3], Loss: 0.1416
# Epoch [393/500], Step [3/3], Loss: 0.1416
# Epoch [394/500], Step [3/3], Loss: 0.1416
# Epoch [395/500], Step [3/3], Loss: 0.1416
# Epoch [396/500], Step [3/3], Loss: 0.1416
# Epoch [397/500], Step [3/3], Loss: 0.1416
# Epoch [398/500], Step [3/3], Loss: 0.1416
# Epoch [399/500], Step [3/3], Loss: 0.1416
# Epoch [400/500], Step [3/3], Loss: 0.1415
# Epoch [401/500], Step [3/3], Loss: 0.1415
# Epoch [402/500], Step [3/3], Loss: 0.1415
# Epoch [403/500], Step [3/3], Loss: 0.1415
# Epoch [404/500], Step [3/3], Loss: 0.1415
# Epoch [405/500], Step [3/3], Loss: 0.1415
# Epoch [406/500], Step [3/3], Loss: 0.1415
# Epoch [407/500], Step [3/3], Loss: 0.1415
# Epoch [408/500], Step [3/3], Loss: 0.1415
# Epoch [409/500], Step [3/3], Loss: 0.1415
# Epoch [410/500], Step [3/3], Loss: 0.1415
# Epoch [411/500], Step [3/3], Loss: 0.1415
# Epoch [412/500], Step [3/3], Loss: 0.1415
# Epoch [413/500], Step [3/3], Loss: 0.1415
# Epoch [414/500], Step [3/3], Loss: 0.1415
# Epoch [415/500], Step [3/3], Loss: 0.1415
# Epoch [416/500], Step [3/3], Loss: 0.1415
# Epoch [417/500], Step [3/3], Loss: 0.1415
# Epoch [418/500], Step [3/3], Loss: 0.1415
# Epoch [419/500], Step [3/3], Loss: 0.1415
# Epoch [420/500], Step [3/3], Loss: 0.1415
# Epoch [421/500], Step [3/3], Loss: 0.1414
# Epoch [422/500], Step [3/3], Loss: 0.1414
# Epoch [423/500], Step [3/3], Loss: 0.1414
# Epoch [424/500], Step [3/3], Loss: 0.1414
# Epoch [425/500], Step [3/3], Loss: 0.1414
# Epoch [426/500], Step [3/3], Loss: 0.1414
# Epoch [427/500], Step [3/3], Loss: 0.1414
# Epoch [428/500], Step [3/3], Loss: 0.1414
# Epoch [429/500], Step [3/3], Loss: 0.1414
# Epoch [430/500], Step [3/3], Loss: 0.1414
# Epoch [431/500], Step [3/3], Loss: 0.1414
# Epoch [432/500], Step [3/3], Loss: 0.1414
# Epoch [433/500], Step [3/3], Loss: 0.1414
# Epoch [434/500], Step [3/3], Loss: 0.1414
# Epoch [435/500], Step [3/3], Loss: 0.1414
# Epoch [436/500], Step [3/3], Loss: 0.1414
# Epoch [437/500], Step [3/3], Loss: 0.1414
# Epoch [438/500], Step [3/3], Loss: 0.1414
# Epoch [439/500], Step [3/3], Loss: 0.1414
# Epoch [440/500], Step [3/3], Loss: 0.1414
# Epoch [441/500], Step [3/3], Loss: 0.1414
# Epoch [442/500], Step [3/3], Loss: 0.1414
# Epoch [443/500], Step [3/3], Loss: 0.1413
# Epoch [444/500], Step [3/3], Loss: 0.1413
# Epoch [445/500], Step [3/3], Loss: 0.1413
# Epoch [446/500], Step [3/3], Loss: 0.1413
# Epoch [447/500], Step [3/3], Loss: 0.1413
# Epoch [448/500], Step [3/3], Loss: 0.1413
# Epoch [449/500], Step [3/3], Loss: 0.1413
# Epoch [450/500], Step [3/3], Loss: 0.1413
# Epoch [451/500], Step [3/3], Loss: 0.1413
# Epoch [452/500], Step [3/3], Loss: 0.1413
# Epoch [453/500], Step [3/3], Loss: 0.1413
# Epoch [454/500], Step [3/3], Loss: 0.1413
# Epoch [455/500], Step [3/3], Loss: 0.1413
# Epoch [456/500], Step [3/3], Loss: 0.1413
# Epoch [457/500], Step [3/3], Loss: 0.1413
# Epoch [458/500], Step [3/3], Loss: 0.1413
# Epoch [459/500], Step [3/3], Loss: 0.1413
# Epoch [460/500], Step [3/3], Loss: 0.1413
# Epoch [461/500], Step [3/3], Loss: 0.1413
# Epoch [462/500], Step [3/3], Loss: 0.1413
# Epoch [463/500], Step [3/3], Loss: 0.1413
# Epoch [464/500], Step [3/3], Loss: 0.1412
# Epoch [465/500], Step [3/3], Loss: 0.1412
# Epoch [466/500], Step [3/3], Loss: 0.1412
# Epoch [467/500], Step [3/3], Loss: 0.1412
# Epoch [468/500], Step [3/3], Loss: 0.1412
# Epoch [469/500], Step [3/3], Loss: 0.1412
# Epoch [470/500], Step [3/3], Loss: 0.1412
# Epoch [471/500], Step [3/3], Loss: 0.1412
# Epoch [472/500], Step [3/3], Loss: 0.1412
# Epoch [473/500], Step [3/3], Loss: 0.1412
# Epoch [474/500], Step [3/3], Loss: 0.1412
# Epoch [475/500], Step [3/3], Loss: 0.1412
# Epoch [476/500], Step [3/3], Loss: 0.1412
# Epoch [477/500], Step [3/3], Loss: 0.1412
# Epoch [478/500], Step [3/3], Loss: 0.1412
# Epoch [479/500], Step [3/3], Loss: 0.1412
# Epoch [480/500], Step [3/3], Loss: 0.1412
# Epoch [481/500], Step [3/3], Loss: 0.1412
# Epoch [482/500], Step [3/3], Loss: 0.1412
# Epoch [483/500], Step [3/3], Loss: 0.1412
# Epoch [484/500], Step [3/3], Loss: 0.1411
# Epoch [485/500], Step [3/3], Loss: 0.1411
# Epoch [486/500], Step [3/3], Loss: 0.1411
# Epoch [487/500], Step [3/3], Loss: 0.1411
# Epoch [488/500], Step [3/3], Loss: 0.1411
# Epoch [489/500], Step [3/3], Loss: 0.1411
# Epoch [490/500], Step [3/3], Loss: 0.1411
# Epoch [491/500], Step [3/3], Loss: 0.1411
# Epoch [492/500], Step [3/3], Loss: 0.1411
# Epoch [493/500], Step [3/3], Loss: 0.1411
# Epoch [494/500], Step [3/3], Loss: 0.1411
# Epoch [495/500], Step [3/3], Loss: 0.1411
# Epoch [496/500], Step [3/3], Loss: 0.1411
# Epoch [497/500], Step [3/3], Loss: 0.1411
# Epoch [498/500], Step [3/3], Loss: 0.1411
# Epoch [499/500], Step [3/3], Loss: 0.1411
# Epoch [500/500], Step [3/3], Loss: 0.1411

# %% [markdown]
# # Predict

# %%
x_val = torch.tensor(x_val,dtype=torch.float32).reshape(-1,1)


model.eval()
with torch.no_grad():
    y_val_pred = model(x_val.to(device))
# Affichage
y_val_pred = y_val_pred.detach().cpu().numpy()
plt.scatter(x_val,y_val_pred,label = "prediction")
plt.scatter(x_val,y_val, label ="true")
plt.legend()
plt.title("Prediction vs Exact data")
# Out:
# Text(0.5, 1.0, 'Prediction vs Exact data')

# %% [markdown]
# # Save the model

# %%
path = "./mymodel.pt"

#Sauvegardez toujours votre modèle sur CPU !
model.eval()
model = model.cpu()
state_dict= model.state_dict()
# Save just the state dict
torch.save(state_dict, path)


#Save the model as a pickle object
path = "./mymodel.pkl"
torch.save(model, path)

# %% [markdown]
# # Load the model

# %%
# Load just the state dict

input_size = 1
hidden_size = 32
num_classes = 1
path = "./mymodel.pt"
model = NeuralNet(input_size, hidden_size, num_classes).to(device)
loaded_state_dict = torch.load(path, weights_only=True)
model.load_state_dict(loaded_state_dict)
model.eval()
#Load the pickle object

# Model class must be defined somewhere
path = "./mymodel.pkl"
model = torch.load(path, weights_only=False)
model.eval()
# Out:
# NeuralNet(
#   (fc1): Linear(in_features=1, out_features=32, bias=True)
#   (activation): Sigmoid()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# Le processus de sauvegarde/chargement utilise la syntaxe la plus intuitive et implique le moins de code possible. Enregistrer un modèle de cette manière sauve le module entier en utilisant le module pickle de Python. L'inconvénient de cette approche est que les données sérialisées sont liées aux classes spécifiques et à la structure exacte du répertoire utilisée lors de l'enregistrement du modèle. Cela est dû au fait que pickle n'enregistre pas la classe du modèle elle-même. Au lieu de cela, il enregistre un chemin vers le fichier contenant la classe, qui est utilisé lors du chargement. Pour cette raison, votre code peut rencontrer des problèmes dans divers cas d'utilisation, comme dans d'autres projets ou après des refactorisations.
#
# Une convention courante dans PyTorch consiste à enregistrer les modèles avec l'extension .pt ou .pth.
#
# N'oubliez pas d'appeler model.eval() pour définir les couches de dropout et de normalisation par lots en mode évaluation avant d'exécuter l'inférence. Ne pas le faire entraînera des résultats d'inférence incohérents.

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
torch.save(model.state_dict(), 'model.ckpt')

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 




# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='../../data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='../../data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# %% [markdown]
# # Créer un module custom
#
# Resnet Block / Convolution à Trous/ Layer Normalisation
#
# Exercice : Faire un couche de convolution qui est une combinaison linaire de paramètres

# %% [markdown]
# # Créer un réseau Custom
#
# Construire Resnet18 / Small Mask RCNN

# %% [markdown]
# # Chargement de données efficaces
#
# Dataloader and dataset
#
# Caching data
#
#
#
# Exercice : accélérer au maximum le chargement des donnée
